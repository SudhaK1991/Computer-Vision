# %% [markdown]
# **HAAR Cascade Classifiers**
#
# Object Detection using Haar feature-based cascade classifiers is an effective object detection method. It is a machine learning based approach where a cascade function is trained from a lot of positive and negative images. It is then used to detect objects in other images.
#
# for more details refer this link
#
# https://docs.opencv.org/3.4/db/d28/tutorial_cascade_classifier.html

# %% [markdown]
# **Import Library**

# %%
import cv2
import numpy as np

# %%
pip install opencv-contrib-python
# Out:
# Requirement already satisfied: opencv-contrib-python in /usr/local/lib/python3.6/dist-packages (4.1.2.30)
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.6/dist-packages (from opencv-contrib-python) (1.18.5)

# %%
from google.colab.patches import cv2_imshow

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import cv2

# %%
## Step:1 make classifier object of haarcascade_frontalface_default.xml
face_classifier = cv2.CascadeClassifier('/content/drive/My Drive/haarcascade_frontalface_default.xml')

# Step:2 Load image
image = cv2.imread('/content/drive/My Drive/kalam.jpg', cv2.IMREAD_UNCHANGED)

# Step:3 Our classifier returns the ROI of the detected face as a tuple
# It stores the top left coordinate and the bottom right coordiantes
faces = face_classifier.detectMultiScale(image)

# %%
# Step: 4 When no faces detected, face_classifier returns 'no faces found'
if faces is ():
    print("No faces found")

# %%
# Step 5 :Draw a rectangle over each face in faces
for (x,y,w,h) in faces: # x, y :- coordinate and w & h are width and height
                        #initial limit, upper limit, color coordinate 
    cv2.rectangle(image, (x,y),(x+w,y+h),(127,0,255),2)

# %%
plt.imshow(image)
plt.show()

# %%
## Step:1 make eye classifier object of haarcascade_eye.xml
## Step:1 make classifier object of haarcascade_frontalface_default.xml
face_classifier = cv2.CascadeClassifier('/content/drive/My Drive/haarcascade_frontalface_default.xml')
eye_classifier = cv2.CascadeClassifier('/content/drive/My Drive/haarcascade_eye.xml')

# %%
# Load image from Google Colab
img = cv2.imread('/content/drive/My Drive/sharukh.webp', cv2.IMREAD_UNCHANGED)
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

faces = face_classifier.detectMultiScale(gray, 1.3, 5)

# When no faces detected, face_classifier returns and empty tuple
if faces is ():
    print("No Face Found")

for (x,y,w,h) in faces:
    cv2.rectangle(img,(x,y),(x+w,y+h),(127,0,255),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = img[y:y+h, x:x+w]
    eyes = eye_classifier.detectMultiScale(roi_gray)
for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(255,255,0),2)
        plt.imshow(img)
        plt.show()
